# %%
# importing important libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
avocado = pd.read_csv('Avocado.csv')
avocado
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
# ...

# %%
avocado.head(3)
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany

# %%
avocado.tail(3)
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046     4225  \
# 18246           9  2018-01-21          1.87      13766.76  1191.92  2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63  2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77  2356.13
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# 18246  727.94     9394.11     9351.80       42.31          0.0  organic  2018
# 18247  727.01    10969.54    10919.54       50.00          0.0  organic  2018
# 18248  224.53    12014.15    11988.14       26.01          0.0  organic  2018
#
#                  region
# 18246  WestTexNewMexico
# 18247  WestTexNewMexico
# 18248  WestTexNewMexico

# %%
avocado.shape
# Out:
# (18249, 14)

# %%
avocado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    18249 non-null  int64
#  1   Date          18249 non-null  object
#  2   AveragePrice  18249 non-null  float64
#  3   Total Volume  18249 non-null  float64
#  4   4046          18249 non-null  float64
#  5   4225          18249 non-null  float64
#  6   4770          18249 non-null  float64
#  7   Total Bags    18249 non-null  float64
#  8   Small Bags    18249 non-null  float64
#  9   Large Bags    18249 non-null  float64
#  10  XLarge Bags   18249 non-null  float64
#  11  type          18249 non-null  object
#  12  year          18249 non-null  int64
#  13  region        18249 non-null  object
# dtypes: float64(9), int64(2), object(3)
# memory usage: 1.9+ MB

# %%
avocado.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'AveragePrice', 'Total Volume', '4046', '4225',
#        '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type',
#        'year', 'region'],
#       dtype='object')

# %% [markdown]
# ## Summary Statistics

# %%
avocado.describe()
# Out:
#          Unnamed: 0  AveragePrice  Total Volume          4046          4225  \
# count  18249.000000  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04
# mean      24.232232      1.405978  8.506440e+05  2.930084e+05  2.951546e+05
# std       15.481045      0.402677  3.453545e+06  1.264989e+06  1.204120e+06
# min        0.000000      0.440000  8.456000e+01  0.000000e+00  0.000000e+00
# 25%       10.000000      1.100000  1.083858e+04  8.540700e+02  3.008780e+03
# 50%       24.000000      1.370000  1.073768e+05  8.645300e+03  2.906102e+04
# 75%       38.000000      1.660000  4.329623e+05  1.110202e+05  1.502069e+05
# max       52.000000      3.250000  6.250565e+07  2.274362e+07  2.047057e+07
#
#                4770    Total Bags    Small Bags    Large Bags    XLarge Bags  \
# count  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000
# mean   2.283974e+04  2.396392e+05  1.821947e+05  5.433809e+04    3106.426507
# ...

# %%
avocado.AveragePrice.unique()
# Out:
# array([1.33, 1.35, 0.93, 1.08, 1.28, 1.26, 0.99, 0.98, 1.02, 1.07, 1.12,
#        1.31, 1.11, 1.34, 1.45, 1.05, 1.37, 1.27, 1.32, 1.23, 1.19, 1.43,
#        1.2 , 1.22, 1.13, 1.16, 1.06, 1.17, 1.24, 0.96, 1.  , 1.09, 0.95,
#        0.97, 1.15, 1.01, 1.14, 1.1 , 1.04, 1.03, 1.18, 1.29, 1.25, 0.71,
#        0.94, 0.91, 1.39, 1.4 , 1.36, 1.3 , 1.54, 1.59, 1.56, 1.38, 1.49,
#        1.5 , 1.47, 1.42, 1.41, 1.44, 1.52, 0.9 , 0.87, 0.78, 0.92, 0.83,
#        0.88, 0.84, 0.85, 1.21, 0.79, 0.89, 0.86, 0.8 , 0.82, 0.74, 0.81,
#        0.77, 0.75, 0.65, 0.73, 0.68, 0.72, 0.67, 0.76, 0.62, 0.7 , 0.66,
#        1.46, 0.49, 0.53, 0.56, 0.6 , 0.58, 0.54, 0.52, 0.51, 0.57, 0.63,
#        0.64, 0.61, 1.48, 1.55, 1.58, 1.53, 1.57, 1.51, 0.69, 1.62, 1.63,
#        1.61, 1.6 , 1.73, 1.8 , 1.86, 1.85, 1.69, 1.66, 1.65, 1.64, 1.67,
#        1.68, 1.82, 2.07, 1.84, 1.83, 1.7 , 1.72, 1.81, 1.78, 0.59, 1.9 ,
#        1.93, 1.99, 1.95, 1.89, 1.76, 1.71, 1.74, 0.55, 1.79, 1.75, 1.94,
# ...

# %%
avocado.AveragePrice.value_counts()
# Out:
# 1.15    202
# 1.18    199
# 1.08    194
# 1.26    193
# 1.13    192
#        ...
# 2.91      1
# 2.68      1
# 3.04      1
# 3.17      1
# 3.03      1
# Name: AveragePrice, Length: 259, dtype: int64

# %%
avocado.type.value_counts(dropna=False)
# Out:
# conventional    9126
# organic         9123
# Name: type, dtype: int64

# %%
avocado.year.value_counts(dropna=False)
# Out:
# 2017    5722
# 2016    5616
# 2015    5615
# 2018    1296
# Name: year, dtype: int64

# %% [markdown]
# ## Finding Null Values

# %%
# checking if there is any null value present in the dataset usinh heatmap
sns.heatmap(avocado.isnull(),cmap="Blues",annot=True)
plt.title("Correlation Matrix")
plt.show()

# %%
# checking the null value without using visualization
avocado.isnull().sum()

# No null value present
# Out:
# Unnamed: 0      0
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %%
sns.jointplot(x='Small Bags', y='Total Bags', data = avocado, color = 'Blue')

# %%
sns.jointplot(x='Large Bags', y='Total Bags', data = avocado, color = "red")

# %%
sns.jointplot(x='XLarge Bags', y='Total Bags', data = avocado, color="green")

# %%
plt.figure(figsize=(12,8))
sns.boxplot(x='year', y='AveragePrice', data = avocado, color ='blue')
plt.title(" Average Price Across the Years")
plt.show()

# %%
plt.figure(figsize=(12,8))
plt.title("Distribution of Average Price")
price = avocado['AveragePrice'].values
sns.distplot(price, color = 'red')
# Out:
# <AxesSubplot:title={'center':'Distribution of Average Price'}, ylabel='Density'>

# %%
from pandas import datetime

avocado['Date'] = pd.to_datetime(avocado['Date'])

avo = avocado['type']=='conventional'
sns.factorplot('Date','AveragePrice',data=avocado[avo], hue='year', size=10)

# %%
avocado['Date'] = pd.to_datetime(avocado['Date'])

avo = avocado['type']=='organic'
sns.factorplot('Date','AveragePrice',data=avocado[avo], hue='year', size=10,palette='deep')

# %%
avocado['Month'] = avocado['Date'].dt.month
avo = avocado['type']=='conventional'
sns.factorplot('Month','region',data=avocado[avo],hue='year',size=12,aspect=0.8)

# %%
avocado['Month'] = avocado['Date'].dt.month
avo = avocado['type']=='organic'
sns.factorplot('Month','region',data=avocado[avo],hue='year',size=12,aspect=0.8)

# %%
plt.figure(figsize=(12,8))
plt.title(" AveragePrice Aganst Type")
sns.set_style('whitegrid')
sns.countplot(x='AveragePrice', hue = 'type', data = avocado)
# Out:
# <AxesSubplot:title={'center':' AveragePrice Aganst Type'}, xlabel='AveragePrice', ylabel='count'>

# %%
plt.scatter(avocado['year'],avocado['AveragePrice'])

# %%
plt.scatter(avocado['Month'],avocado['AveragePrice'])

# %%
avocado['Total Bags'].plot.box()
# Out:
# <AxesSubplot:>

# %%
sns.factorplot('AveragePrice','region',data=avocado,hue='type',size=12,aspect=0.8,palette='winter',join=False)

# %%
tvol= avocado[['4046', '4225', '4770']]
tvol.plot(kind='line', figsize =(12,8))
plt.title("Total Number of Avocado Sold")
plt.show()

# %%
# Bivariate Analysis
sns.pairplot(avocado)

# %%
sns.pairplot(avocado,hue="Total Volume" , palette = 'husl' ,size = 1)

# %% [markdown]
# ## Checking Correlation

# %%
dfcor = avocado.corr()
dfcor
# Out:
#               Unnamed: 0  AveragePrice  Total Volume      4046      4225  \
# Unnamed: 0      1.000000     -0.133008      0.014035  0.017628  0.019829
# AveragePrice   -0.133008      1.000000     -0.192752 -0.208317 -0.172928
# Total Volume    0.014035     -0.192752      1.000000  0.977863  0.974181
# 4046            0.017628     -0.208317      0.977863  1.000000  0.926110
# 4225            0.019829     -0.172928      0.974181  0.926110  1.000000
# 4770            0.041752     -0.179446      0.872202  0.833389  0.887855
# Total Bags     -0.002219     -0.177088      0.963047  0.920057  0.905787
# Small Bags      0.000347     -0.174730      0.967238  0.925280  0.916031
# Large Bags     -0.009196     -0.172940      0.880640  0.838645  0.810015
# XLarge Bags    -0.011546     -0.117592      0.747157  0.699377  0.688809
# year           -0.171667      0.093197      0.017193  0.003353 -0.009559
# Month          -0.777730      0.162409     -0.024689 -0.025803 -0.022108
#
# ...

# %%
# generating heatmap to check the correlation among features
plt.figure(figsize=(12,8))
sns.heatmap(dfcor, cmap='ocean_r', linewidths=2, fmt=".2f",annot=True)
# darker colour represent very positive correlation where as light color represent negative correlation
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Cleansing of data

# %%
avocado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    18249 non-null  int64
#  1   Date          18249 non-null  datetime64[ns]
#  2   AveragePrice  18249 non-null  float64
#  3   Total Volume  18249 non-null  float64
#  4   4046          18249 non-null  float64
#  5   4225          18249 non-null  float64
#  6   4770          18249 non-null  float64
#  7   Total Bags    18249 non-null  float64
#  8   Small Bags    18249 non-null  float64
#  9   Large Bags    18249 non-null  float64
#  10  XLarge Bags   18249 non-null  float64
#  11  type          18249 non-null  object
#  12  year          18249 non-null  int64
#  13  region        18249 non-null  object
#  14  Month         18249 non-null  int64
# dtypes: datetime64[ns](1), float64(9), int64(3), object(2)
# memory usage: 2.1+ MB

# %%
avocado.shape
# Out:
# (18249, 15)

# %%
df_avocado = avocado
df_avocado.shape
# Out:
# (18249, 15)

# %%
# dropping Unnamed, date and region as we do not have any use at this point in time
df_avocado.drop(['Unnamed: 0','Date','Month'], inplace=True,axis=1)

# %%
# Replacing type object variable to integer
df_avocado['type'] = df_avocado["type"].replace({"conventional":1,"organic":0})

# %%
#Importing label encoder to convert region feature
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()

# %%
df_avocado['region'] = label_encoder.fit_transform(df_avocado['region'])

# %% [markdown]
# ## Plotting Outliers

# %%
# checking whether there are any outliner present
# importing important libraries

from scipy.stats import zscore

z_score = abs(zscore(df_avocado))
print(df_avocado.shape)
df_avo = df_avocado.loc[(z_score<3).all(axis=1)]
print(df_avo.shape)

#Outliners have been removed
# Out:
# (18249, 12)
# (17651, 12)

# %%
collist =df_avo.columns.values
ncol = 12
nrows = 10

# %%
# graphical representation of data
plt.figure(figsize=(ncol,5*ncol))
for i in range(1, len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(df_avo[collist[i]], color = 'green', orient = 'v')
    plt.tight_layout()

# %% [markdown]
# ## Checking if skewness is present

# %%
# finding skewness if there are any
df_avo.skew()
# data shows there are positive skewness present
# Out:
# AveragePrice    0.377432
# Total Volume    3.767138
# 4046            4.909848
# 4225            4.455745
# 4770            5.117170
# Total Bags      4.066771
# Small Bags      4.222706
# Large Bags      5.053434
# XLarge Bags     6.135607
# type            0.037741
# year            0.229976
# region          0.012798
# dtype: float64

# %%
# Graphical representation
plt.figure(figsize=(24,24))
for i in range(0,len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.distplot(df_avo[collist[i]])

# %%
# treating the skewness with log
import numpy as np
for col in df_avo.columns:
    if df_avo.skew().loc[col]>0.55:
        df_avo[col] = np.log1p(df_avo[col])

df_avo.skew()
# Out:
# AveragePrice    0.377432
# Total Volume   -0.049950
# 4046           -0.420273
# 4225           -0.604619
# 4770            0.068532
# Total Bags     -0.384493
# Small Bags     -0.788988
# Large Bags     -0.610874
# XLarge Bags     1.216238
# type            0.037741
# year            0.229976
# region          0.012798
# dtype: float64

# %%
# XLarge Bags still has skewness, treating it with square root transformation

list = ['XLarge Bags']
for i in list:
    df_avo[i]=np.sqrt(df_avo[i])
    
df_avo.skew()
# Out:
# AveragePrice    0.377432
# Total Volume   -0.049950
# 4046           -0.420273
# 4225           -0.604619
# 4770            0.068532
# Total Bags     -0.384493
# Small Bags     -0.788988
# Large Bags     -0.610874
# XLarge Bags     0.930995
# type            0.037741
# year            0.229976
# region          0.012798
# dtype: float64

# %%
# XLarge Bags still has skewness, treating it with cube root transformation

list = ['XLarge Bags']
for i in list:
    df_avo[i]=np.cbrt(df_avo[i])
    
df_avo.skew()
# Out:
# AveragePrice    0.377432
# Total Volume   -0.049950
# 4046           -0.420273
# 4225           -0.604619
# 4770            0.068532
# Total Bags     -0.384493
# Small Bags     -0.788988
# Large Bags     -0.610874
# XLarge Bags     0.780282
# type            0.037741
# year            0.229976
# region          0.012798
# dtype: float64

# %%
# Seperating input and output for classification
df_avo.shape
# Out:
# (17651, 12)

# %%
# defining x features
x=df_avo.iloc[:,1:]
x.head(3)
# Out:
#    Total Volume      4046       4225      4770  Total Bags  Small Bags  \
# 0     11.070344  6.944801  10.905146  3.895080    9.070833    9.060055
# 1     10.912867  6.515127  10.706381  4.083115    9.159737    9.149429
# 2     11.680313  6.679222  11.600485  4.879007    9.005325    8.992584
#
#    Large Bags  XLarge Bags  type  year  region
# 0    4.545951          0.0     1  2015       0
# 1    4.589955          0.0     1  2015       0
# 2    4.645736          0.0     1  2015       0

# %%
# defining y variable
y=df_avo.iloc[:,:1]
y.head(3)
# Out:
#    AveragePrice
# 0          1.33
# 1          1.35
# 2          0.93

# %%
x.shape
# Out:
# (17651, 11)

# %%
y.shape
# Out:
# (17651, 1)

# %%
# scaling down using standard scaler
# importing libraries
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)
x
# Out:
# array([[-0.06196232, -0.58731803,  0.43156498, ...,  1.01904715,
#         -1.21001338, -1.69549505],
#        [-0.13430157, -0.71946434,  0.35960138, ...,  1.01904715,
#         -1.21001338, -1.69549505],
#        [ 0.21823548, -0.66899685,  0.68331601, ...,  1.01904715,
#         -1.21001338, -1.69549505],
#        ...,
#        [-0.76950251, -0.54445811, -0.69071773, ..., -0.98130886,
#          1.98075592,  1.74705401],
#        [-0.69459605, -0.46819541, -0.62012644, ..., -0.98130886,
#          1.98075592,  1.74705401],
#        [-0.65956156, -0.27170762, -0.70526836, ..., -0.98130886,
#          1.98075592,  1.74705401]])

# %% [markdown]
# ## Data is ready for Machine Learning

# %%
# importing important libraries

from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import Lasso
from sklearn.ensemble import GradientBoostingRegressor

# %%
# finding best random state between 42 to 100 with test_size=0.20
max_r_score = 0
for r_state in range(42,101):
    x_train, x_test, y_train, y_test = train_test_split(x, y, random_state = r_state, test_size=0.20)
    lr = LinearRegression()
    lr.fit(x_train, y_train)
    y_predict = lr.predict(x_test)
    r2_scr = r2_score(y_test, y_predict)
    print("r2_score corresponding to random state: ",r_state," is: ", r2_scr)
    if r2_scr > max_r_score:
        max_r_score = r2_scr
        final_r_state = r_state
    print()
    print()
    print("Maximum r2 score corresponding to",final_r_state, "is ",max_r_score)
# Out:
# r2_score corresponding to random state:  42  is:  0.519609985952233
#
#
# Maximum r2 score corresponding to 42 is  0.519609985952233
# r2_score corresponding to random state:  43  is:  0.5295313907829351
#
#
# Maximum r2 score corresponding to 43 is  0.5295313907829351
# r2_score corresponding to random state:  44  is:  0.49966231557622565
#
#
# Maximum r2 score corresponding to 43 is  0.5295313907829351
# r2_score corresponding to random state:  45  is:  0.5223133887250653
#
#
# Maximum r2 score corresponding to 43 is  0.5295313907829351
# r2_score corresponding to random state:  46  is:  0.5275306209589701
#
#
# Maximum r2 score corresponding to 43 is  0.5295313907829351
# r2_score corresponding to random state:  47  is:  0.5083763240054675
#
#
# Maximum r2 score corresponding to 43 is  0.5295313907829351
# r2_score corresponding to random state:  48  is:  0.5106493837342762
#
#
# Maximum r2 score corresponding to 43 is  0.5295313907829351
# ...

# %%
# since the maximun r2 score is comming around 0.53 with random state 60. As the score is very low 
# hence checking with other models
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state = 60, test_size = 0.20)

# %%
x_train.shape
# Out:
# (14120, 11)

# %%
y_train.shape
# Out:
# (14120, 1)

# %%
x_test.shape
# Out:
# (3531, 11)

# %%
y_test.shape
# Out:
# (3531, 1)

# %%
# finding the best parameters for each model using gridsearchCV

# %%
svr=SVR()
parameters = {'kernel':('linear','poly','rbf'), 'C':[1,10]}
svgs = GridSearchCV(svr, parameters, cv = 5)
svgs.fit(x_train,y_train)
svgs.best_params_
# Out:
# {'C': 10, 'kernel': 'rbf'}

# %%
knn = KNeighborsRegressor()
parameters = {'n_neighbors':range(1,30)}
knngs = GridSearchCV(knn, parameters, cv = 5)
knngs.fit(x_train, y_train)
knngs.best_params_
# Out:
# {'n_neighbors': 3}

# %%
rfr = RandomForestRegressor()
parameters = {'n_estimators':[100,299]}
rfgs = GridSearchCV(rfr, parameters, cv = 5)
rfgs.fit(x_train, y_train)
rfgs.best_params_
# Out:
# {'n_estimators': 299}

# %%
dtr = DecisionTreeRegressor()
parameters = {'criterion':('mse','friendman_mse', 'mse')}
dtgs = GridSearchCV(dtr, parameters, cv = 5)
dtgs.fit(x_train, y_train)
dtgs.best_params_
# Out:
# {'criterion': 'mse'}

# %%
lso = Lasso()
parameters = {'alpha':[0.001,0.01,0.1,1]}
lsgs = GridSearchCV(lso, parameters, cv = 5)
lsgs.fit(x_train, y_train)
lsgs.best_params_
# Out:
# {'alpha': 0.001}

# %%
gbr = GradientBoostingRegressor()
parameters = {'learning_rate':[0.001,0.01,0.1,1], 'n_estimators':[10,100,500,1000]}
gbgs = GridSearchCV(gbr, parameters, cv = 5)
gbgs.fit(x_train, y_train)
gbgs.best_params_
# Out:
# {'learning_rate': 0.1, 'n_estimators': 1000}

# %%
lr = LinearRegression()
svr = SVR(C=10, kernel = 'rbf')
knn = KNeighborsRegressor(n_neighbors = 3)
rfr = RandomForestRegressor(n_estimators = 299)
dtr = DecisionTreeRegressor(criterion ='mse')
lso = Lasso(alpha =0.001 )
gbr = GradientBoostingRegressor(learning_rate = 0.1, n_estimators = 1000)

# %%
models = []
models.append(('LineatRegression', lr))
models.append(('SVR', svr))
models.append(('KNeighborsRegressor', knn))
models.append(('RandomForestRegressor', rfr))
models.append(('DecisionTreeRegressor', dtr))
models.append(('Lasso', lso))
models.append(('GradientBoostingRegressor', gbr))

# %%
# Testing all required models with best parameters calculated

Model = []
score = []
rmse = []
mae = []
mse = []
cvs = []
std = []

for name,model in models:
    print ('******************', name ,'********************')
    print("\n")
    Model.append(name)
    model.fit(x_train, y_train)
    print(model)
    pred = model.predict(x_test)
    print("\n")
    rscore = r2_score(y_test, pred)
    print("r2 Score =", rscore)
    score.append(rscore*100)
    print("\n")
    RMS = np.sqrt(mean_squared_error(y_test, pred))
    print("RMSE =", RMS)
    rmse.append(RMS*100)
    print("\n")
    MA = mean_absolute_error(y_test, pred)
    print("MAE =", MA)
    mae.append(MA*100)
    print("\n")
    MS = mean_squared_error(y_test, pred)
    print("MSE =", MS)
    mse.append(MS*100)
    print("\n")
    cvscore = cross_val_score(model, x, y, cv = 10).mean()
    print("Cross_Val_Score =", cvscore)
    cvs.append(cvscore*100)
    print("\n")
    stdscore = cross_val_score(model, x, y, cv = 10).std()
    print("Standard Deviation =", stdscore)
    std.append(stdscore*100)
    print("\n\n")
# Out:
# ****************** LineatRegression ********************
#
#
# LinearRegression()
#
#
# r2 Score = 0.5353603983208819
#
#
# RMSE = 0.267469214062449
#
#
# MAE = 0.2111765884236563
#
#
# MSE = 0.07153978047118416
#
#
# Cross_Val_Score = 0.1088500576352696
#
#
# Standard Deviation = 0.13963296134337536
#
#
#
# ****************** SVR ********************
#
#
# SVR(C=10)
#
#
# r2 Score = 0.7589430240946193
#
#
# RMSE = 0.1926528962461209
#
#
# MAE = 0.14153593984995455
#
#
# MSE = 0.03711513843201862
#
#
# Cross_Val_Score = -0.1289810290112196
#
#
# Standard Deviation = 0.6373766450144592
#
#
#
# ****************** KNeighborsRegressor ********************
#
#
# KNeighborsRegressor(n_neighbors=3)
#
#
# r2 Score = 0.8503648512954046
#
#
# RMSE = 0.151786273993131
#
#
# MAE = 0.10561408477296326
#
#
# MSE = 0.02303907297271783
#
#
# Cross_Val_Score = 0.01574572516630467
#
#
# Standard Deviation = 0.20126369113411935
#
#
#
# ****************** RandomForestRegressor ********************
#
#
# ...

# %%
import pandas as pd
result = pd.DataFrame({'Model': Model, 'r2_score': score, 'Root_mean_square': rmse, 'Mean_absolute_error': mse, 'Mean_square_error': mse, 'Cross_val_score_mean': cvs, 'Cross_val_score_Std': std})
result
# Out:
#                        Model   r2_score  Root_mean_square  \
# 0           LineatRegression  53.536040         26.746921
# 1                        SVR  75.894302         19.265290
# 2        KNeighborsRegressor  85.036485         15.178627
# 3      RandomForestRegressor  84.620065         15.388381
# 4      DecisionTreeRegressor  67.545065         22.354042
# 5                      Lasso  53.422051         26.779710
# 6  GradientBoostingRegressor  79.768673         17.649316
#
#    Mean_absolute_error  Mean_square_error  Cross_val_score_mean  \
# 0             7.153978           7.153978             10.885006
# 1             3.711514           3.711514            -12.898103
# 2             2.303907           2.303907              1.574573
# 3             2.368023           2.368023             34.303805
# 4             4.997032           4.997032            -27.299196
# 5             7.171529           7.171529             11.038204
# ...

# %%
# The above result shows that KNeighborsRegressor is giving the best result

# %%
import joblib
joblib.dump(knn,'Avocado_KNeighbor.csv')
# Out:
# ['Avocado_KNeighbor.csv']

# %%
model=joblib.load('Avocado_KNeighbor.csv')

# %%
model.predict(x_test)
# Out:
# array([[1.01      ],
#        [1.46333333],
#        [1.38666667],
#        ...,
#        [1.69666667],
#        [1.27666667],
#        [1.69      ]])
